# %%
import cv2
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
import numpy as np
import math
import random

# %%
img = cv2.imread('dinosaur.jpg')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img , cmap = "gray")

# %%
x , y = (img.shape)
print(x,y)
# Out:
# 770 1155

# %%
filter = np.ones([3, 3], dtype = int)
filter = - filter
filter[1,1] = - 8 * filter[1,1]
print(filter)
# Out:
# [[-1 -1 -1]
#  [-1  8 -1]
#  [-1 -1 -1]]

# %%
highPassed_filtered = np.zeros([x, y])
for i in range(1, x-1):
  for j in range(1, y-1):
    temp = (img[i-1, j-1]*filter[0, 0] + img[i-1, j]*filter[0, 1] +
      img[i-1, j + 1]*filter[0, 2] + img[i, j-1]*filter[1, 0] +
      img[i, j]*filter[1, 1] + img[i, j + 1]*filter[1, 2] +
      img[i + 1, j-1]*filter[2, 0] + img[i + 1, j]*filter[2, 1] +
      img[i + 1, j + 1]*filter[2, 2])
    highPassed_filtered[i, j]= temp

# %%
cv2_imshow(highPassed_filtered)
# Out:
# <PIL.Image.Image image mode=L size=1155x770 at 0x7F34A8265EE0>

# %%
a = 1.5
filter = np.ones([3, 3], dtype = int)
filter = - filter
filter[1,1] = -( 8 + a )* filter[1,1]
highBoost_filtered = np.zeros([x, y])
for i in range(1, x-1):
  for j in range(1, y-1):
    temp = (img[i-1, j-1]*filter[0, 0] + img[i-1, j]*filter[0, 1] +
      img[i-1, j + 1]*filter[0, 2] + img[i, j-1]*filter[1, 0] +
      img[i, j]*filter[1, 1] + img[i, j + 1]*filter[1, 2] +
      img[i + 1, j-1]*filter[2, 0] + img[i + 1, j]*filter[2, 1] +
      img[i + 1, j + 1]*filter[2, 2])
    highBoost_filtered[i, j]= temp

# %%
cv2_imshow(highBoost_filtered)
# Out:
# <PIL.Image.Image image mode=L size=1155x770 at 0x7F34A825FEE0>

# %% [markdown]
# **Conclusion**
#
# 1)In high pass filtering it highlights the fine details in the image thus we are above to identify the borders and some importants lines in the image while removing the background.
#
# 2)In high boost filtering it enhances the image and also retains the background thus seeing the image in greater detail.
