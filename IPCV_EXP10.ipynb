# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# #### PREWITTS OPERATOR

# %%
img = cv2.imread('/content/Scramble.svg.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
kernelx = np.array([[1,1,1],[0,0,0],[-1,-1,-1]])
kernely = np.array([[-1,0,1],[-1,0,1],[-1,0,1]])
img_prewittx = cv2.filter2D(img, -1, kernelx)
img_prewitty = cv2.filter2D(img, -1, kernely)

# %%
plt.imshow(img_prewittx, cmap='gray')

# %%
plt.imshow(img_prewitty, cmap='gray')

# %%
plt.imshow(img_prewittx + img_prewitty, cmap='gray')

# %% [markdown]
# #### SOBEL OPERATOR

# %%
img=cv2.imread('/content/Scramble.svg.png',cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')

# %%
kernelx1 = np.array([[-1,-2,-1],[0,0,0],[1,2,1]])
kernely1 = np.array([[-1,0,1],[-2,0,2],[-1,0,1]])
img_sobelx = cv2.filter2D(img, -1, kernelx)
img_sobely = cv2.filter2D(img, -1, kernely)

# %%
plt.imshow(img_sobelx,cmap='gray')

# %%
plt.imshow(img_sobely,cmap='gray')
